# %%
from utils import *

# %% [markdown]
# **a)**
# $$ f(x,y,z) = (x - z)^2 + (2y + z)^2 + (4x - 2y + z)^2 $$
# With initial points (0, 0, 0) and (1, 1, 0) and actual minima at f(-1/6, -11/48, 1/6) = 19/96

# %%
x1_1 = np.array([0,0,0])
x1_2 = np.array([1,1,0])
x_min = np.array([-1/6,-11/48,1/6])
gammas = np.array([[0.005, 0.005, 0.005, 0.5],
                   [0.005, 0.005, 0.005, 0.5]])
v = 0.9

optimizing_functions = ['Gradient descent', 'Polyak GD', 'Nesterov GD', 'AdaGrad', 'Newton method', 'BFGS']

# %% [markdown]
# Plots and results for different **number of steps**:

# %%
T = 2
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 0.17918058166666667
# Gradient descent for starting point (1.0, 1.0): 8.083079061666668
# Polyak GD for starting point (0.0, 0.0): 0.1711323316666667
# Polyak GD for starting point (1.0, 1.0): 6.961604811666667
# Nesterov GD for starting point (0.0, 0.0): 0.17143009981666668
# Nesterov GD for starting point (1.0, 1.0): 7.100455412616668
# AdaGrad for starting point (0.0, 0.0): 5.854869389822366
# AdaGrad for starting point (1.0, 1.0): 1.6645191649484121
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 0.08678111440000003
# BFGS for starting point (1.0, 1.0): 5.2266552071702455

# %%
T = 5
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 0.15599076117649138
# Gradient descent for starting point (1.0, 1.0): 5.813443916558177
# Polyak GD for starting point (0.0, 0.0): 0.10498884587875128
# Polyak GD for starting point (1.0, 1.0): 3.9995405049458554
# Nesterov GD for starting point (0.0, 0.0): 0.10673321130607583
# Nesterov GD for starting point (1.0, 1.0): 3.1104940844844813
# AdaGrad for starting point (0.0, 0.0): 0.10791331627594242
# AdaGrad for starting point (1.0, 1.0): 0.770671030600043
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 0.04142772537697892
# BFGS for starting point (1.0, 1.0): 0.8319880246001587

# %%
T = 10
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 0.1260050398714358
# Gradient descent for starting point (1.0, 1.0): 3.9389321471760432
# Polyak GD for starting point (0.0, 0.0): 0.03423279757988129
# Polyak GD for starting point (1.0, 1.0): 0.8854519025239083
# Nesterov GD for starting point (0.0, 0.0): 0.034027833972256866
# Nesterov GD for starting point (1.0, 1.0): 0.5950094224357017
# AdaGrad for starting point (0.0, 0.0): 0.023140494267822442
# AdaGrad for starting point (1.0, 1.0): 0.14287897702274371
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 0.04079704981416393
# BFGS for starting point (1.0, 1.0): 0.798469013463236

# %%
T = 100
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 0.0074634829054125995
# Gradient descent for starting point (1.0, 1.0): 0.11349279105286839
# Polyak GD for starting point (0.0, 0.0): 8.013353125779776e-07
# Polyak GD for starting point (1.0, 1.0): 6.764483711679814e-05
# Nesterov GD for starting point (0.0, 0.0): 3.3385053860301994e-07
# Nesterov GD for starting point (1.0, 1.0): 5.0729827503204206e-06
# AdaGrad for starting point (0.0, 0.0): 7.341349750333848e-14
# AdaGrad for starting point (1.0, 1.0): 1.7300050281221502e-13
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 2.7755575615628914e-17
# BFGS for starting point (1.0, 1.0): 0.0

# %% [markdown]
# Plots and results for different number of **time limits**:

# %%
plot_all(x1_1, x1_2, x_min, gammas, 0.8, 100000, 0.01, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 6.186190448786988e-12
# Gradient descent for starting point (1.0, 1.0): 1.9512169657787126e-13
# Polyak GD for starting point (0.0, 0.0): 2.7755575615628914e-17
# Polyak GD for starting point (1.0, 1.0): 2.7755575615628914e-17
# Nesterov GD for starting point (0.0, 0.0): 0.0
# Nesterov GD for starting point (1.0, 1.0): 2.7755575615628914e-17
# AdaGrad for starting point (0.0, 0.0): 2.7755575615628914e-17
# AdaGrad for starting point (1.0, 1.0): 2.7755575615628914e-17
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 2.7755575615628914e-17
# BFGS for starting point (1.0, 1.0): 0.0

# %%
plot_all(x1_1, x1_2, x_min, gammas, 0.8, 100000, 0.1, optimizing_functions, f1, 1)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (0.0, 0.0): 8.326672684688674e-17
# Gradient descent for starting point (1.0, 1.0): 0.0
# Polyak GD for starting point (0.0, 0.0): 2.7755575615628914e-17
# Polyak GD for starting point (1.0, 1.0): 2.7755575615628914e-17
# Nesterov GD for starting point (0.0, 0.0): 0.0
# Nesterov GD for starting point (1.0, 1.0): 2.7755575615628914e-17
# AdaGrad for starting point (0.0, 0.0): 2.7755575615628914e-17
# AdaGrad for starting point (1.0, 1.0): 2.7755575615628914e-17
# Newton method for starting point (0.0, 0.0): 5.551115123125783e-17
# Newton method for starting point (1.0, 1.0): 0.0
# BFGS for starting point (0.0, 0.0): 2.7755575615628914e-17
# BFGS for starting point (1.0, 1.0): 0.0

# %% [markdown]
# **FINAL THOUGHTS:**
#
# All methods converge for this function in only 0.01 seconds (or lower). We can see that the newton method converges in only 2 steps for both initial points.
