# %%
from utils import *

# %% [markdown]
# **b)**
# $$ f(x,y,z) = (x-1)^2 + (y-1)^2 + 100(y-x^2)^2 + 100(z-y^2)^2 $$
# With initial points  (1.2, 1.2, 1.2) and  (−1, 1.2, 1.2) and actual minima at f(1, 1, 1) = 0

# %% [markdown]
# Plots and results for different **number of steps**:

# %%
x1_1 = np.array([1.2, 1.2, 1.2])
x1_2 = np.array([-1, 1.2, 1.2])
x_min = np.array([1,1,1])

gammas = np.array([[0.001, 0.001, 0.001, 1],
                   [0.002, 0.002, 0.0011, 0.1]])
v = 0.9

optimizing_functions = ['Gradient descent', 'Polyak GD', 'Nesterov GD', 'AdaGrad', 'Newton method', 'BFGS']

# %%
T = 2
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 0.04237239125217779
# Gradient descent for starting point (-1.0, 1.2): 167.69402389629977
# Polyak GD for starting point (1.2, 1.2): 4.697759342110983
# Polyak GD for starting point (-1.0, 1.2): 19.390170395073916
# Nesterov GD for starting point (1.2, 1.2): 0.4899328351996322
# Nesterov GD for starting point (-1.0, 1.2): 20.484241438607715
# AdaGrad for starting point (1.2, 1.2): 100.21139255011019
# AdaGrad for starting point (-1.0, 1.2): 4.503819532224463
# Newton method for starting point (1.2, 1.2): 0.03541789639141939
# Newton method for starting point (-1.0, 1.2): 9.06184326595489
# BFGS for starting point (1.2, 1.2): 0.21365289506341395
# BFGS for starting point (-1.0, 1.2): 4.2395146365122365

# %%
T = 5
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 0.018222956182597522
# Gradient descent for starting point (-1.0, 1.2): 27.244364054736316
# Polyak GD for starting point (1.2, 1.2): 0.16120151829822965
# Polyak GD for starting point (-1.0, 1.2): 7.1717959970622935
# Nesterov GD for starting point (1.2, 1.2): 0.12700467058936898
# Nesterov GD for starting point (-1.0, 1.2): 27.609412903365623
# AdaGrad for starting point (1.2, 1.2): 66.60586925597653
# AdaGrad for starting point (-1.0, 1.2): 4.254894167737044
# Newton method for starting point (1.2, 1.2): 4.066868659398174e-05
# Newton method for starting point (-1.0, 1.2): 4.236227155366453
# BFGS for starting point (1.2, 1.2): 0.025796381930705558
# BFGS for starting point (-1.0, 1.2): 4.214711534872593

# %%
T = 10
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 0.01810864030289777
# Gradient descent for starting point (-1.0, 1.2): 0.1423549826034139
# Polyak GD for starting point (1.2, 1.2): 4.26608375373788
# Polyak GD for starting point (-1.0, 1.2): 3.6516278965878732
# Nesterov GD for starting point (1.2, 1.2): 3.144180434613193
# Nesterov GD for starting point (-1.0, 1.2): 5.549947865171116
# AdaGrad for starting point (1.2, 1.2): 0.26811124739218467
# AdaGrad for starting point (-1.0, 1.2): 4.249381210653298
# Newton method for starting point (1.2, 1.2): 0.0
# Newton method for starting point (-1.0, 1.2): 1156.4276738703034
# BFGS for starting point (1.2, 1.2): 0.018111758382415688
# BFGS for starting point (-1.0, 1.2): 4.2123366128111535

# %%
T = 100
plot_all(x1_1, x1_2, x_min, gammas, v, T, None, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 0.01687469219992976
# Gradient descent for starting point (-1.0, 1.2): 0.1047983820482448
# Polyak GD for starting point (1.2, 1.2): 0.0010714402038432423
# Polyak GD for starting point (-1.0, 1.2): 0.03398161001713718
# Nesterov GD for starting point (1.2, 1.2): 0.09215574861613922
# Nesterov GD for starting point (-1.0, 1.2): 0.10842739363198
# AdaGrad for starting point (1.2, 1.2): 0.1661184537953878
# AdaGrad for starting point (-1.0, 1.2): 4.154354174708249
# Newton method for starting point (1.2, 1.2): 0.0
# Newton method for starting point (-1.0, 1.2): 0.0
# BFGS for starting point (1.2, 1.2): 0.0
# BFGS for starting point (-1.0, 1.2): 0.007078288316002863

# %% [markdown]
# Plots and results for different number of **time limits**:

# %%
plot_all(x1_1, x1_2, x_min, gammas, 0.9, 100000, 0.01, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 0.009737166204463046
# Gradient descent for starting point (-1.0, 1.2): 0.9426240641167267
# Polyak GD for starting point (1.2, 1.2): 5.954102446610519e-07
# Polyak GD for starting point (-1.0, 1.2): 9.667505097775222e-09
# Nesterov GD for starting point (1.2, 1.2): 0.0002048800014771435
# Nesterov GD for starting point (-1.0, 1.2): 0.004319968838962929
# AdaGrad for starting point (1.2, 1.2): 0.0661194587448404
# AdaGrad for starting point (-1.0, 1.2): 3.7829019241209045
# Newton method for starting point (1.2, 1.2): 0.0
# Newton method for starting point (-1.0, 1.2): 0.0
# BFGS for starting point (1.2, 1.2): 0.0
# BFGS for starting point (-1.0, 1.2): 0.06705449835964016

# %%
plot_all(x1_1, x1_2, x_min, gammas, v, 100000, 0.1, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 5.9246488031231226e-05
# Gradient descent for starting point (-1.0, 1.2): 0.6552389718154638
# Polyak GD for starting point (1.2, 1.2): 8.976846738526546e-25
# Polyak GD for starting point (-1.0, 1.2): 1.9967584370600866e-25
# Nesterov GD for starting point (1.2, 1.2): 0.001009979144792606
# Nesterov GD for starting point (-1.0, 1.2): 0.0020745930357674654
# AdaGrad for starting point (1.2, 1.2): 0.04139999173028866
# AdaGrad for starting point (-1.0, 1.2): 0.05994473199317749
# Newton method for starting point (1.2, 1.2): 0.0
# Newton method for starting point (-1.0, 1.2): 0.0
# BFGS terminating.
# BFGS for starting point (1.2, 1.2): 0.0
# BFGS for starting point (-1.0, 1.2): 0.0

# %%
plot_all(x1_1, x1_2, x_min, gammas, v, 100000, 1, optimizing_functions, f2, 2)
# Out:
# Difference between final function value and minima function value:
#
# Gradient descent for starting point (1.2, 1.2): 1.0578295133206044e-22
# Gradient descent for starting point (-1.0, 1.2): 0.6520885493271087
# Polyak GD for starting point (1.2, 1.2): 8.976846738526546e-25
# Polyak GD for starting point (-1.0, 1.2): 1.9967584370600866e-25
# Nesterov GD for starting point (1.2, 1.2): 0.0002171473201424825
# Nesterov GD for starting point (-1.0, 1.2): 0.14535011909773266
# AdaGrad for starting point (1.2, 1.2): 4.047214847944936e-23
# AdaGrad for starting point (-1.0, 1.2): 1.407531712562035e-19
# Newton method for starting point (1.2, 1.2): 0.0
# Newton method for starting point (-1.0, 1.2): 0.0
# BFGS terminating.
# BFGS for starting point (1.2, 1.2): 0.0
# BFGS for starting point (-1.0, 1.2): 0.0

# %% [markdown]
# **FINAL THOUGHTS:**
#
# All descent methods converge on this function, except normal gradient descent for second initial point.
#
#
# With early termination (if next step was sufficiently small terminate) we see that newton's method performs best with smallest number of steps (10 for first initial point and 35 with second).
